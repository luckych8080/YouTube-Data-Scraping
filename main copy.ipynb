# %%
from googleapiclient.discovery import build
import pandas as pd
import seaborn as sns

# %%
apikey = ''
# channel_id = 'UCTJkhuZ2HqdJr_8p4KGBA6A'
channel_ids = ['UCTJkhuZ2HqdJr_8p4KGBA6A', 
            'UC8OCoGX9tmMneOzIFUTWq2Q',
            'UCS7UIBUDGBnUXyXcV1DyHOg', 
            'UCOkywXyXAPDP3E_aykq0XFQ',
            'UCZg2qhgQHxC9RXhkIiwA6kw',
            'UC_ovpykq47grPDSlhzciLYQ',
            'UCSrDe6ZsresHsA7ApTY-Sdw',
            'UCcGjTW1U2g_7oZgrjnYRoUg',
            'UC-n8szdwFgv4eAoO-GKbGNA',
            'UCqZeVBcZvtRS8XfNjCk-JTw',
            'UCsPECr25ykgt6bwYExM7KvA']

youtube = build('youtube', 'v3', developerKey=apikey)

# %% [markdown]
# ## Function to get channel statistics

# %%
def get_channel_stats(youtube, channelID):
    all_data = []
    request = youtube.channels().list(
        part='snippet, contentDetails, statistics', id=channelID)

    response = request.execute()

    for i in range(len(response['items'])):
        data = dict(Channel_Name = response['items'][i]['snippet']['title'],
                    Subscribers = response['items'][i]['statistics']['subscriberCount'],
                    Views = response['items'][i]['statistics']['viewCount'],
                    Total_videos = response['items'][i]['statistics']['videoCount'],
                    Started_At = response['items'][i]['snippet']['publishedAt'],
                    # Description = response['items'][i]['snippet']['description'],
                    Playlist_id = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)

    return all_data

# %%
channels_statistics = get_channel_stats(youtube, channel_ids)

# %%
channels_data = pd.DataFrame(channels_statistics)

# %%
# channels_data

# %% [markdown]
# ## Function to get video ids

# %%
channels_data
# Out:
#                      Channel_Name Subscribers      Views Total_videos
# 0                         R.S SIR      624000  118966141         6939  \
# 1   BYJU'S Exam Prep- NDA Express      106000   11039159         3729
# 2          CADETS DEFENCE ACADEMY      529000   62089299         2010
# 3      Self Selection Board - SSB      285000   23561003          741
# 4       Unacademy Defence Gurukul       49400    4515907         2302
# 5         Examपुर Defence Warrior     1360000  141400340        17312
# 6                  Defence Wallah      701000   54669951         1380
# 7         Unique Defence Academy        30300    1687311          465
# 8                Learn with Sumit      264000   32076797         2751
# 9                     NDA Adda247       29200    1413951         2127
# 10      Centurion Defence Academy      438000   90764657         4799
#
#                      Started_At               Playlist_id
# 0          2017-07-17T15:50:00Z  UUTJkhuZ2HqdJr_8p4KGBA6A
# 1   2020-12-23T10:56:30.062624Z  UU-n8szdwFgv4eAoO-GKbGNA
# 2   2020-06-27T18:04:57.258515Z  UU_ovpykq47grPDSlhzciLYQ
# 3          2018-12-16T02:42:11Z  UUSrDe6ZsresHsA7ApTY-Sdw
# 4   2022-09-22T06:55:14.037661Z  UUcGjTW1U2g_7oZgrjnYRoUg
# 5          2018-10-18T10:22:37Z  UUOkywXyXAPDP3E_aykq0XFQ
# 6   2021-08-14T19:33:14.730509Z  UU8OCoGX9tmMneOzIFUTWq2Q
# 7   2021-06-19T02:09:16.632371Z  UUZg2qhgQHxC9RXhkIiwA6kw
# 8          2013-11-28T17:29:22Z  UUqZeVBcZvtRS8XfNjCk-JTw
# 9   2022-05-10T11:06:59.185291Z  UUsPECr25ykgt6bwYExM7KvA
# 10         2016-05-08T05:40:02Z  UUS7UIBUDGBnUXyXcV1DyHOg

# %%
channels_data.to_csv('All_Channels_data.csv', index=False)

# %%
playlist_id = channels_data.loc[channels_data['Channel_Name']=="Unacademy Defence Gurukul", 'Playlist_id'].iloc[0]

# %%
def get_vedio_ids(youtube, playlist_id):
    request = youtube.playlistItems().list(
        part='contentDetails', playlistId = playlist_id,
        maxResults = 50)
    response = request.execute()

    video_ids = []

    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])


    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 100,
                pageToken = next_page_token)
            response = request.execute()

            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])

            next_page_token = response.get('nextPageToken')

    return video_ids

# %%
video_ids = get_vedio_ids(youtube, playlist_id)

# %%
video_ids
# Out:
# ['onOFKEURMZ8',
#  'Ss_BSXF1SUc',
#  'JzySjvqHCdo',
#  'etW0ecjmRR0',
#  'PyBevBac6ZE',
#  'bxbbV0EkLR4',
#  'CEKmOBwpAwI',
#  'w9Pe-Mu4hEA',
#  'X496XoKcqHs',
#  '_jpJ1UzW2QQ',
#  'lYTwttI3PB0',
#  'gZaPG2HqqZY',
#  'LrqZeG1MWuo',
#  'MjqB1xgLyVE',
#  'JpyOeVJdWuM',
#  'qzXRDwVFw5o',
#  '8w_ti9hjzN4',
#  'km0fEKceLls',
#  'qg9fO79yxBI',
#  'u5Z2CZNLj2A',
#  'LnWnBsJIIU4',
#  '6hcyz4XDKYk',
#  '5iiEzsgzQgI',
#  'mGgHIVAW83Y',
#  'lrvKAjyn9V0',
#  'rjW3RiOSJAM',
#  'ek_Dn6aSKbA',
#  'YVzwdtBVsmE',
#  'gCMmaJ7Ujx0',
#  'i8ROIKAog24',
#  'JV9hS2wh_9A',
#  'OswR8xooTxU',
#  'Y9vblgjKJvw',
#  'R9Y1Yg50Odo',
#  '_gkauPywu0g',
#  '-Y231VJOl1M',
#  'H2WXdppv9Bg',
#  'g0_CfmxVIio',
#  'stQnbcLrp9o',
#  '9lB0x7b8ZB4',
#  'Ej5XqHzOxV8',
#  'D9ITfZsYtK0',
#  'gohdkgDtzp8',
#  'XBuW2-m9rvI',
#  'v2Nz89ZoqvM',
#  'PG1Jj9ORqyc',
#  'bblKiqW3wAw',
#  'y8U42aEvhOQ',
#  '844vVCpOa9I',
#  'bipjzkr5Lko',
#  'F-jbk-FUMLw',
#  'XuteL98VgDg',
#  'uf3E22JcWfQ',
#  'HYT73EAHSXg',
#  '6d7TsDeiH-8',
#  'vUs33dG4lYo',
#  'nZCznnToPGM',
#  'IvLuAZ7VMv8',
#  'rW1yq__jjV0',
#  'JTThDGkagII',
#  '5EC1YYXvSt4',
#  'KPwgfJDgF8w',
#  '-pUN4ya6biM',
#  'mIOeYylOXaE',
#  '4LoJFeVmrpw',
#  'pJcDhp5C3zg',
#  'IYGZxgU2I40',
#  'qMp0MfJ5Oe4',
#  'dfVa_y2KxDI',
#  'ghbZMUUBv8U',
#  'HWZgSuywIpg',
#  'wfys7h5sW8I',
#  'f_sDksyjZS4',
#  'dQAm67dHA1s',
#  '-5vL8jC31Zw',
#  'bHvvRfqjG8I',
#  'cNS4dffotkU',
#  'JyMYqop6Qms',
#  'hOBmy_S8VAQ',
#  'PD6zoFukyFs',
#  '4ikABH0STNw',
#  '6fHolD77Xys',
#  'rom0gP3M5E8',
#  'rsB74hSHnWY',
#  'a1vIwV_zUqM',
#  'Hu10a_LZIoo',
#  'UnJbOx9pdOc',
#  'k4p8y00d2AE',
#  'wZTpNaj_VFc',
#  'SZppJnNwqSY',
#  'iasqYEEJvUY',
#  'yOVRYPjeDCw',
#  'PESTptv06_U',
#  'dZz2aO2ouyg',
#  'vHe5MLAIE7I',
#  '2bAHfABrUJo',
#  'T-mDBUcKME4',
#  'sUBtJQF8uTQ',
#  'ls_72jh47xU',
#  'JV-x4J2w8gI',
#  'jX5KTt1bE4A',
#  'FPXJH4UAng8',
#  'kWrS3cipZ94',
#  'xdn9MOPQDhA',
#  'AH-9-goRNMg',
#  'voQ9w2CnWdE',
#  'hvzDDAv6fXg',
#  'DWkqWwbdcWM',
#  'FLjgpS7cVcM',
#  '1qDiEqXOykw',
#  'Q9DhxrfClD8',
#  'DdP6nVioIb0',
#  '1QX17gifwY4',
#  'qhjJheyI7LM',
#  '6cXfPSoApk8',
#  'COs7v6R7uc8',
#  'iFvhH0ZjyUM',
#  'V4SMgSrtTxw',
#  'ONxWmSqEH9s',
#  'vx9bsFEDm0k',
#  'EgB6GhkBi1Y',
#  'OQt4iwH7TCw',
#  'Z16LLWtK8uk',
#  '3t5lA75NhOw',
#  'AVoPiVXQEKM',
#  'AG4A9ELzwMw',
#  'jrxsqd1w8CM',
#  'dD5z4ksIMfs',
#  '61xBKgkSNHQ',
#  'OW0dccVcwhI',
#  'aOgdKw8CRhQ',
#  'i1S3u_82FOI',
#  'u1ZZN20VyCA',
#  'DPq3s7xwt8E',
#  'd-lkAud5VSc',
#  'gVGOOHSifHo',
#  'xja99cw-qNY',
#  '12K8sn1Uu6s',
#  'BB0JKgNsPVo',
#  'q0bhDI-hy3o',
#  '1KspnXRGamc',
#  'SsuQP9Z6xGU',
#  'R9PSnpgra4M',
#  'T5bHV5fqfOc',
#  '_oFNi3ddSvk',
#  'lgnFEfUGnyU',
#  '7b5gTbBbjx8',
#  'k2YhnuPThNc',
#  '4U21RBmt_W4',
#  'zA2EzAjWRfY',
#  'juiPnw7g0-4',
#  '-cMh4kBMweY',
#  'qbetf2FLtV8',
#  'txU-f77BkF0',
#  'hIiKGdiJm7o',
#  'NJcQVngOI_M',
#  'vzWMXYxUN1s',
#  'MgXF8z_MWLk',
#  '1HSzp6Kf1Po',
#  'CPKFgvoxzaw',
#  'HlzmlGiY5LI',
#  '7VQ-Aia-7IU',
#  'dS_iIP6FZYY',
#  'cCKsUUQMCgI',
#  '_rIdXV6gNbc',
#  'Oxq71zEBBiU',
#  'Ak6KQLl0Ddg',
#  'lGnv_Bioja0',
#  'A9eh8ucETG8',
#  'iiR8HRLViZ0',
#  'NXTpSFbsGdk',
#  'gfaWb5gHY6U',
#  'cHMDc-ItX0Q',
#  '3ZvFI8RDAwg',
#  'TcQVjRtr4_c',
#  'xJ7UWsqFyJU',
#  'FfoT2cRh1nQ',
#  'UuIi7sX39v4',
#  'heBFyI2dSPg',
#  'ZTz8d1CIyTc',
#  'F6YEUNLlXXE',
#  '2n97lAWwXJk',
#  'WoRdT0XPLMA',
#  'lGoFIwLALOM',
#  'QzJqtHNCA8U',
#  '3C1XglB4EuM',
#  'FrsTMc8-O8M',
#  's3gaYEj4VnA',
#  'gBBjKTR2Wnc',
#  'oy6I0uEYSpw',
#  'LI0AUipwyKc',
#  'vgo_eBnEbNk',
#  '238tcmjuDFg',
#  'QeiMggJQRsk',
#  'nWVy6wPCwi0',
#  'Scds-lEo84I',
#  '3ma4yg0qk2Y',
#  'vEnjh20liOw',
#  'YNg8eYivyGw',
#  '3cLBScytD-E',
#  'OHV_zWTkUGk',
#  '6AAHMtdQfW8',
#  'ry3QcDJG7-4',
#  'kIqdN9O-BJM',
#  'P8dOP9PAvWU',
#  '_9bhG98db3Q',
#  'HjCGcsH7Ee0',
#  'qwrKZKL_9NU',
#  'ru4rP0G88cc',
#  'BGqEOxq_93I',
#  'd1W6oGOKp1I',
#  'MssrU7EdTsw',
#  'aW4UhLPqaSc',
#  'JN7Ag41Z9aw',
#  'G9fDW1M08xw',
#  'nrrOeeb6xnQ',
#  '7fbhrAdtcl4',
#  'rYd_Ywz3bP4',
#  'oelqQeLUxIQ',
#  'HxUTLW8kbBo',
#  'WX9wUWRR-8E',
#  'UYdCeab4xoI',
#  '8aa8qdfdGu8',
#  'j1rOCX9Yohk',
#  '0IMiouaTmOI',
#  'uxeA8wm2jZg',
#  'JcaP2qN8fv8',
#  '0bkRwQhzQv0',
#  'sO57FYhQ2ck',
#  'IbY51kk_AOE',
#  '60GLIABW1ks',
#  'MCCrEJSZeH8',
#  'sGLzbKwIzIs',
#  '9tLMY33N1CA',
#  'LD-1mIhmAoM',
#  'W_wlQBCC4Sk',
#  'j9oDY3e3dDw',
#  'sdktkVxJXVc',
#  'mKqImZvvCks',
#  'BMfygye2jys',
#  'Aco88ugtDas',
#  '2aYHX0chOWM',
#  'UazVErZGDq8',
#  'BSv-ch0XW24',
#  'dDwvjNjkB24',
#  'tkCREYLRTTs',
#  'wtC1yj6gpbc',
#  'Bo5_Teth3QQ',
#  'h7MEEc3uHmw',
#  'r4RvuP7PBGU',
#  'SnyjqNuZ-t0',
#  'dsTdkIHgR7A',
#  'jTWCltPFTgE',
#  'lkciDKeHYiM',
#  'ngxQI5MXHpE',
#  'dQYENFV30Nc',
#  'kX9pDVc7jX4',
#  '9wtuLL8PDXU',
#  'AZ_rHaID1Fw',
#  'o3Oe3mWTk2w',
#  'ALTwWJzkegQ',
#  'nKSDPba7Ljs',
#  'B9M5JXAt4h0',
#  'RKHlphcg4oY',
#  'Cvx2JbZsy7g',
#  '2jIMRQfhK_8',
#  'TR41TdmFwko',
#  'DIrWUURFtDo',
#  'GIwIHgqv9mI',
#  'fjPYhukGetk',
#  'Q6tZN-SFzsM',
#  'SrVwEspaUU8',
#  'wO2CL98i9lk',
#  'BOuZ-UfoI5M',
#  'GserLJ1Fb4c',
#  'XBA3kEXgG6c',
#  'wQc5WTtEYSo',
#  'hX_Bz4TVTVs',
#  'OfIb8P9PjYs',
#  '96sj8G-n_38',
#  'U9iOspwjsBg',
#  '2ECnzPHM3sU',
#  'CcinPHJgj0c',
#  'Ns3hTRFx-d4',
#  'Tw8YBQ_pH2c',
#  'M-h4kLNaJHw',
#  'ZS0V1jha-Qc',
#  'HBG6c7tvlmY',
#  '_17qmqTLH5s',
#  'X5VQ_KAsy_k',
#  '_TjBzC7meDY',
#  'QrXJqVb4Qm0',
#  'xvHqisgnjOc',
#  '67p_mnSI6qQ',
#  'f8P4CRHR96A',
#  'LzkMbNQFHE4',
#  '54dc7kIrQAw',
#  'OC3YVuKagBY',
#  'ww95E3a4AF0',
#  'ghp7cS_UtYY',
#  'fIUNx3bvcWI',
#  'DlvY_ZVnTy0',
#  '-EMSNsefMp8',
#  'yqVBh7mRRaY',
#  'J5YTQbccun4',
#  'G0Xn7oZmd70',
#  'KCtSkZ3fW6A',
#  'gThG9gjYea8',
#  'tBWKwnTp648',
#  'JDxu7WHWC2I',
#  'sS4e4ZRV2hk',
#  'mb9CPeA7LmA',
#  'hltkJijNXX4',
#  'tRE8yNJljtM',
#  '_9EfL6vF35A',
#  'MyCPC5soKDc',
#  'blZyaIE082I',
#  'MMSEVMt4xNo',
#  'eZdj9L4oM2I',
#  '-fwQaSUAFM4',
#  'Zim2klP-fj4',
#  '3brSXkVZ6xc',
#  'P6uSb_AXprk',
#  'D31LnZM5ntM',
#  'iyilPXe8mqw',
#  '7wMYdZ_zVd4',
#  'eWrx-_gWzWQ',
#  'YwSEci4SATs',
#  'KLGvcXT0wXY',
#  '9EXhySeSb_I',
#  'ie3U0vbN5R8',
#  'KmP24q14kBk',
#  '5whTNwuXUvI',
#  '0u81rGZC4Es',
#  'owlH74IEbWA',
#  'zhbrvPo0jx4',
#  '1TiBH-_Jg4g',
#  'CaCdOu_LshU',
#  '09wCsK0BAdQ',
#  'Znc8cs0jTq4',
#  'Y8YhHT_YD4Y',
#  '2UL1098Pekk',
#  'ER1CJMcfTpE',
#  'cqCcfXFkwQI',
#  'WQH87hjrUZw',
#  'Ya-twq8FFwE',
#  'zEzZcufvUwE',
#  'ngGKqCgL0-w',
#  'pYT_UioXib8',
#  'qSXD5oqnJXw',
#  '-pzSsuIrUQM',
#  'RQ6biTS2T8U',
#  '_01O5TrAJdU',
#  'oLmjKhcNkP4',
#  'gGcQv96jOkA',
#  '2gOyxRtSHYI',
#  'n4dvsd1LhpQ',
#  'wrjpwY3mpn8',
#  'MHO6Q2ULTOw',
#  'lsKlLV7axqE',
#  'Yilkyr6hndw',
#  'YRFPpxqGvcM',
#  'QrYK_HaAnRc',
#  'JYh72Z4kyO0',
#  '31NzMJdJvQU',
#  'gXqLcNtT6E8',
#  'kFFWdPtN-yU',
#  'ttNccQz-dp4',
#  '8T8uV9U4bhs',
#  'MPLAHdoHCCg',
#  '2wMwOAnVXas',
#  'ns21ON4Piq8',
#  'M264roTCUkQ',
#  '5f6acRkx3V8',
#  'Kos95SPXlbw',
#  'x9VVNEIEQ38',
#  'BFW_exVcMKc',
#  '78oh5Q8OTzs',
#  'M12eiBIA-lw',
#  'rn87eK0Gl3Y',
#  'jWW2uJKJbSw',
#  'EVaFxp1tutk',
#  'boWJ3Mi_-rk',
#  'V-UAnpRkurs',
#  'w9ShEgeYYnQ',
#  '21IEjPQjPMA',
#  'xqgac8Wd3Vo',
#  'RGlQpgxNQPg',
#  'FtK_u89YNSs',
#  'I58ucgJ3chA',
#  'rbIHGjwfot4',
#  'fSqUIveEupA',
#  'KmkENDAS2vQ',
#  'RV5O3nRtl4s',
#  '2MtWwsnAXW0',
#  'I9qlSyg5sgw',
#  'C5z1OKeX7S4',
#  '74ZlZ7OKms4',
#  'LHfkV0Uu-ho',
#  '7NnddCF7kI4',
#  '8_AQ6BotYIs',
#  'vLTs7n_QOuY',
#  '2exLVVuKU70',
#  'Woanqpl7M94',
#  'OkF3iRftTqs',
#  'sFTKrVsCYD4',
#  '5ao1kd8mdIA',
#  'dhdymB4Vg4w',
#  '2QninVb2nyE',
#  '7WA8sUV0nzQ',
#  'tUY0ZHqwrKY',
#  'ZNCvN68jTHU',
#  'VdlurrAD2T8',
#  'dpOZoGYFLj0',
#  'vqpcsFoYOVQ',
#  'RVL8jTY2Epk',
#  '7w-L0okcYgk',
#  '459kGI9sVjU',
#  'PKMosrlnOOE',
#  'nQ-RZOH9qK4',
#  'LcEvzkdGT7c',
#  'CLo2soDn8Pc',
#  '3X80PhiCyjA',
#  'C5eGQu9qXTY',
#  '6iWdlVAMQSk',
#  'OweuE_jluhQ',
#  'oaSFZpoSi8A',
#  '5P1ZPkFypm4',
#  'NaHlVUwM6XU',
#  '2JJsBcUiP_k',
#  'Tyqw0Mj7Hz4',
#  'tpBUkFBgQKE',
#  'zuDwVRAmKP8',
#  '15D4XIxfecY',
#  'y_VOYKw0Tbk',
#  'E9KlrQcT3l8',
#  'yZTGMjb06yA',
#  'hyKmJFVLKPc',
#  'dmpfPeMEPn8',
#  'nV0Tifuw5eU',
#  'tFhKLcbyAtc',
#  'efMJXnTKQC8',
#  'JX4P02aVAD8',
#  'u-ags_BvNhs',
#  'SquL-ib_YmM',
#  '23imaAet7b8',
#  'n_1_u1GaY64',
#  'L_OFvZ4IYlE',
#  'oVNhZqvdjWY',
#  '6gvAKQ_U3EQ',
#  'Rey-M3Pf_XM',
#  '8DJ32eqxtkA',
#  'PUb-bjMAnLc',
#  'erok5AxI8h0',
#  '3rwRg6BybwY',
#  'R4PmWGOoaTE',
#  'rWYw9mcAQPY',
#  'JnzvnWFcaoc',
#  '3l04Fc0cJhc',
#  'pTlf7QUCNHk',
#  '8DWhyB94tJ4',
#  'rYF1RaFp5qo',
#  'aqeiWNoIxoY',
#  'JiMcm5otmPY',
#  '3z1rk0VqybM',
#  'pxvdMZez6ps',
#  'xTEiLMEz9eM',
#  '4s3hth3H2lM',
#  'kMcearnKpCw',
#  'gc-6rNfEZAU',
#  'ZWvmCLDNFmU',
#  'KZAuLgPl1vc',
#  'zYmBuv-pNnA',
#  '0cwtGYQlQAs',
#  '6YScFH8WV7s',
#  '77gXLJaod5A',
#  '0XeTUFQrj-o',
#  '413dNJM2fow',
#  '7ofKqeyYAzc',
#  'gdONaEEbDRM',
#  'uHY2HylGzAo',
#  'wLZhfeGOuaA',
#  '5eO7VBglmHI',
#  'ZbA5ZLjcnbM',
#  'HOJqVWizIl4',
#  'j4emSuBMfso',
#  'Arly9Ju5Pvg',
#  'T3N9xyVJ-7Q',
#  'cTWUzla3Vj0',
#  'GjXP7Z3dIsc',
#  'nf0VCNQOj04',
#  'v5NEgZDDAZM',
#  '_A6zjfp3koM',
#  'lAMojHDcB9M',
#  'z99rDlU8nE8',
#  'xPT_5-vWplU',
#  '7e9Qh_mzOC8',
#  'ta66nvHRnMo',
#  '7b22bcFChhw',
#  'FE1q8l7Slt4',
#  'J0cYS4NPciI',
#  'zF3lMsYr1KI',
#  'K0cF3MDTqIU',
#  'lb0-nh5FGyE',
#  'eaAEgcmxH6o',
#  '20s_4_tuFxQ',
#  'oJ9ilkFq7Jw',
#  'eLt2Lle4394',
#  'W4AMrA2VUjA',
#  'l99Zm0m-luU',
#  'voBcwcf27bU',
#  'DXKyodUDnEA',
#  'eHlyhnVArGA',
#  'GYZyGHx5NOQ',
#  'b5IlqTsS7pA',
#  'ICUvW4uprnU',
#  't79j694bsJs',
#  'baV2wbiBev4',
#  '0N1QksHI-8c',
#  'ErPO5uq97-Y',
#  'ZnSQHoJJC2o',
#  'fQeR9A3-2wg',
#  'IAog73ftk-Q',
#  'pN8Na2LLHcY',
#  'eV8BbnpozgI',
#  '4Jv4sV6cgXU',
#  'QL_4_vKTT38',
#  'ZR35d1AcqA0',
#  'BsBxTuBI4PU',
#  'bkUuouePnOo',
#  'mglX3hLf4eU',
#  'MMrJGKnlmQo',
#  'sUGwhg_lWJw',
#  'qZ-xmePjcYA',
#  'cY2qrYKCJGs',
#  'yTgglrBK5WA',
#  'T1_K_1uJRNs',
#  'sG0bPsYelIg',
#  'cB4ghluUea0',
#  'ZpYIysV1eIc',
#  'Ll3YVs7W4q0',
#  '7PsQw3CZWbE',
#  'wPr7KgqWEtA',
#  'JNn3YPILP_0',
#  'erf_9GNWiRU',
#  'JfLRgx8fS8E',
#  'qq6x_aLI42I',
#  'CdDeWgQJ3sM',
#  '2sSPh6SjhiY',
#  'aVgI7OQcJLg',
#  'MxEzrSMzB08',
#  'qzHb8YMd49Q',
#  '86Paf4Clyd8',
#  '_5wAayrmRbY',
#  'OUfW0oXYWSs',
#  'BiUFpBD--Kg',
#  'yoU1HwNEKo4',
#  'm-MF3jQvjrY',
#  'fc1rx7iMXdI',
#  'xtwE1ib3H_g',
#  'L89WLm16dBY',
#  'q5fFLDZN6Ho',
#  'OHoBi6_r00I',
#  'gzJA0UcAl_Q',
#  'GIeOU43PcAA',
#  '3zTDvhZ0PU4',
#  'J643qH8yy1M',
#  'eMIVu0bXaI0',
#  'DMaOOVYRx0Q',
#  '1kMKSGQg1XQ',
#  'PfLBtCZUoAs',
#  'd7YuU7qEUxY',
#  'rlKRraG9jz4',
#  'GII8jPERPfc',
#  'GLhPF0tX3ko',
#  '8owmFizHkNk',
#  'wjozyCcyI3o',
#  'RjYFeESAEzc',
#  't_bVlLluXnc',
#  'DyZgbzeGscM',
#  'HPVWuC595_E',
#  'M7kjU88bR-U',
#  'XLI35hfxeJ0',
#  'yORMa5xucuE',
#  'E9ywCWB5nAs',
#  'kVU_zWX19QU',
#  'KPOMy7AqZlo',
#  'uV4zN38GA3w',
#  'qMI4TYh37qM',
#  '7AHramvjEzo',
#  'wgBDPOJjTQI',
#  'NpS1kXZA2sU',
#  '6Mklkn4n27I',
#  '_6r0S2PR6_U',
#  '2B6F2V4P2Q0',
#  'BkVrzEsfjz8',
#  'ppFm1mRWiy4',
#  'V2O_PFweunA',
#  '0VqvcQOnLqM',
#  'lCSQwsKpJhs',
#  'UAaPjTPVUbE',
#  'G6V8lzyZHYs',
#  'IEKpoMRMlIA',
#  '7Lb0w05ZYFg',
#  'JXCd-VsjLOM',
#  'NV01dTJOBJM',
#  'dmTTdots42A',
#  'yfOBLo4W1tQ',
#  'E47TMb8-K8c',
#  'ZsMfnshY6uI',
#  'NmTnYw5BjFY',
#  '3CBqz8WUv48',
#  'DdZKTCqPM9Y',
#  'IRclu0IQmVw',
#  'z-sJiREefGA',
#  'tC8Rn4vn8o8',
#  'SPHw3yn9YyE',
#  '5CWpQK9OQhI',
#  '_N3T5mSqVs0',
#  'u7YJw_AxiF8',
#  'ID8jxw9nbss',
#  'InUPz9-A7LU',
#  'y1Wy6MKpxGk',
#  'jL2e20VvIjk',
#  '3fHaVukvVr4',
#  'dVD4sDDXuP0',
#  'eh5zvCTjFlY',
#  'BhPwh5yHlpc',
#  'WBkozfv9bsk',
#  '-dZpZxTIQ5U',
#  'O4tqLk-ucao',
#  'P_K086hXDLU',
#  '5XXxX2UtpYg',
#  'c44lj_5iPS8',
#  '-en2ufEY2bc',
#  '80j8iDiSPF0',
#  'eWFg96Ylo-o',
#  'FdLSNFU1JvQ',
#  'fmmDsAPf1FE',
#  'rhzbyHRGfdg',
#  'P0LaBTMUjdI',
#  'bj7oJfIeKGE',
#  'RUxqWD7pZUA',
#  'ASBB2A9ZxIg',
#  'fSF0OVSMAyk',
#  'hwuiRzggMr4',
#  'gpI3-cPxi2A',
#  'eFTsfSJ3YQk',
#  'xDZnGZlvz5I',
#  'pDUUJhoeQJk',
#  'kSRuOfV_ooE',
#  'VVV4WfwfBi0',
#  'lq2F8SDNRx4',
#  'sTZIat44EQM',
#  'iblrv2cRzFY',
#  'FxzAv1METuE',
#  '7qsGIQ5XSTI',
#  'QKZtzoBUXjg',
#  'ibdx_yn947k',
#  'ORsGx1xTzq8',
#  'jzf4LmJU9CY',
#  'cyl1bm9pFWk',
#  'sVItQtMT6Jw',
#  'Cunqqp9OivU',
#  'xxsizRLZgjU',
#  'byELpm2VQ2g',
#  'ZVMviVTCAbc',
#  'rutRgigQTTE',
#  'Ws_Ursz_9w0',
#  '5Rdl2x36hnE',
#  'rvzfBS0zvto',
#  'aqM_FgjYgtI',
#  'to_cBdIDLWg',
#  'lB8MVbhGb58',
#  'vB-rL0nUEdY',
#  'lBKo3WVbsy8',
#  'OikLWh5Ol8s',
#  'XNhQ6_81kf0',
#  '5ze9eKbND8o',
#  'CbZg_WHj6EY',
#  'B6kbf0778Uc',
#  'okaCKHmlI7Y',
#  'SFICsTSMyeE',
#  'tTAj-kHhR7A',
#  '7dgZgIE_Y1c',
#  'rVn09NK1xzA',
#  'EyIpyZSPTto',
#  'S4RcnfvexO8',
#  'xx6ZhPOPiQk',
#  'JCljNzm6J0k',
#  '-JENSjmtvsk',
#  'K5Ou9yQCtLI',
#  '60zNXENyJyM',
#  '_eGBIWx6NKk',
#  'yMhjNYbjSA4',
#  'Kv14CF9Wesw',
#  'Rf78ESeMJ8c',
#  'W4Ylh_lYT5Q',
#  'atFf9pFNT-E',
#  'WPWMrw0FFMQ',
#  'T93q9o5NX98',
#  '_abofNXCqFY',
#  '2oLb0I9RFcs',
#  'A29BWmiaeTM',
#  '5XXKyVETnY4',
#  '_B94a7aEMvA',
#  'NJE-rQ0ny50',
#  'AiRUSf4kZwo',
#  'kVh7cD4Do6M',
#  'nwcJTNXZGwY',
#  'GOa_fa2DTNI',
#  'idvR8ATS2Yg',
#  '3vTse8cwmHY',
#  'E4Suxm5iZHM',
#  '6sDKaZRDMM8',
#  'FwqY8z-UZRI',
#  '623R6PAXGzQ',
#  'SbMy0A4tCPc',
#  'nwpp9gea17U',
#  'tGrN9VvMGIM',
#  '_MxyMWotZNU',
#  '5BJFWiCJf_c',
#  'SLq5ileY5IA',
#  '81Mq4VWl2P4',
#  'CdEzxg8btvM',
#  'lxZNBQ8A1Z8',
#  'sNYCmXukKMI',
#  'aLWA6nCn5Hk',
#  'HGu0Hh0xf6k',
#  'pOtmM9-VuRo',
#  '6hnoTRRVFy0',
#  '8o4kgKAZZ8g',
#  'U-EKzaiefGg',
#  '0XOps155VBw',
#  'abRqtICPDz8',
#  'MMgFEV9bDTs',
#  '7gOYj6bE1_0',
#  'RL-3jJtw54A',
#  '13nLgGusjWc',
#  'oOifCwi9D-o',
#  '-lxur15I2DM',
#  'F9OOZqvJ6FE',
#  'rCuPaHXiSbQ',
#  'gVbO9aoHE74',
#  '4-geJ0UdnJA',
#  'kktNE3zLHB4',
#  'Tn3BKA9hobE',
#  'xTlZOdeT0pY',
#  'gJKkMLExdMo',
#  'IykQHclGPO0',
#  'FoxZfp30rrY',
#  'P5LJ7MKKJ5Q',
#  'Yo5XDt3P00Q',
#  'NyEJbxGXnWk',
#  '7E5Z_sXP5jA',
#  'LvmEXTfdJ8k',
#  'wPcGFHGko7Q',
#  '-WkkNv0WUkI',
#  'ZVk_m_LA7fo',
#  'red5dOjJILo',
#  '4G_JK3RP5Tw',
#  'Ny0skPx2bmU',
#  '6_VdE55D53w',
#  'mARECt_fXcI',
#  'EEaqoZFk6hg',
#  'YKWFO9LKnK0',
#  '1X2-L9pTXiM',
#  'IJXpV8QdL7A',
#  'jigT9gdpDyo',
#  '-x_lDjfPTUg',
#  'jgQUAWYNkB0',
#  'TIV1nQeckes',
#  'N3Uxxn7XVnc',
#  'E-voVXD-mSY',
#  '3cIN3LlF_Pw',
#  'EvYSDOwx4OE',
#  '4p775pUZjks',
#  'yKlXdyTKmPg',
#  '5clr1BCXR14',
#  'E9k1zFRb67c',
#  'FvZ_TzPOWp8',
#  'd0vZ28dmw-4',
#  'KvsgaP-lkhI',
#  'o6L02bCYbqQ',
#  'Zq3ZLAckdmc',
#  'c94_7QWhn5Q',
#  'o3RxmxsWaf8',
#  'ABuC2OUgYHk',
#  'POnUZHT66nU',
#  'ait0Gl99VCs',
#  'saYuuRK412k',
#  'Taijty_6FIE',
#  'u2uvjVHABqw',
#  'ZDoF_D2yqWw',
#  'F8YIUm6vQ80',
#  'FH2rY7snOZo',
#  'Ol3xxc9a-ko',
#  '_62A8g3y_tc',
#  'Q9d0FcZJbCM',
#  'P0IaCiMN3QA',
#  'PQ0ak8MZ7aw',
#  'yKx-L6BQYFA',
#  'DV-7IHoz9PA',
#  'dIZ0KDWk_j8',
#  '226A1gfTFHA',
#  'RLUgK73P6YA',
#  'iNK1cdBcoWs',
#  'Pf-stFHxC50',
#  'JCEc-Yp4PyE',
#  'VMuAkUA6PGo',
#  'cLtzIdhye5c',
#  'ewVg1294bsE',
#  'LoTDfyLV704',
#  'mDBHDf9_k0U',
#  'bsSrZ-nOyV0',
#  'ZOO8KDnSucw',
#  'oyPhqX0OfII',
#  'LrIZQmeK5ZA',
#  'AFWpwWQpMBI',
#  'xfV0yZTgiSU',
#  'UCbtqe8V6u8',
#  'iDzTT-mZPiM',
#  '3Vvb66A1geU',
#  'PkueuxWigoo',
#  'TZL5SdMUhjQ',
#  'wmsRZ_r_tQQ',
#  'DUCIh5dzcdE',
#  'Z4gnt3vOSok',
#  '691H98IPU6o',
#  '0uFIY4KHrUY',
#  'M3D5mCd1UZQ',
#  'QISpfHhyrqs',
#  '8my8R0V4F_E',
#  'FpFfNvHTvA0',
#  '_kIlaD9xo1M',
#  'Xouhlx2Xchc',
#  '5On_OoaTPDk',
#  '26mCyM-fKZw',
#  'SEpgX_G1Leo',
#  'EtILrqtTRdQ',
#  'JpAgom-uBYI',
#  'cArlaM2_XAQ',
#  'GLMWRxU0mwM',
#  'hDirQwGsgEw',
#  'Dwo9WfEVS30',
#  'qsvRGSfYSsc',
#  '7CaaV36BNcU',
#  'R1jGhnDy2c4',
#  'yUwUutHjMBM',
#  'g2EOgmVOLMk',
#  'eq97b8WBfLg',
#  'jQ5G66ziru4',
#  'IRiTcWLjVSo',
#  'LmTW9rFpBHU',
#  'm1lsJlGDLAo',
#  '4v9m2aCRv64',
#  'MAoRa0HxnuA',
#  '-OcdV83ZW38',
#  'vaz9eYvk8cs',
#  'WU9xf_AOEzw',
#  'MmgENRJqUvg',
#  'PN3jZPkboFg',
#  'E7VbOltX3I0',
#  'rNP7RZGc-no',
#  'o2b3gyWJ3Lw',
#  'mJwg815WUDw',
#  'JVeA5ycif4o',
#  'pT1TJqtMHmI',
#  'JXMHbtAvpVU',
#  'OOCgRL5o7Gw',
#  '7tJTrs7Yueo',
#  'l-VC7WqzCiE',
#  'H8ztTqxsoMU',
#  'anvz43JYOes',
#  'uCL4OzoLopM',
#  'ZQWSjo69JgM',
#  'XViUNevoeDM',
#  'sf5X46s5Nt4',
#  '2gOxd2wEQAM',
#  'IvURYFwAAjM',
#  'foQmupmaDTU',
#  'qLdsg0v8eek',
#  't-kNG3SiH2w',
#  'r3QMCynXN2Q',
#  'CTsSMnRcn5A',
#  'PkP6hZZ3aGc',
#  'T5k2wEN0Jys',
#  'DMBfjx0aH2Y',
#  'H7bnA8NZysY',
#  '3cQK6i1j6SY',
#  'Qd8hmRhbG5k',
#  'y2f9J-4fwT0',
#  'MleuZ-yC3Fs',
#  'aenW32GdOTE',
#  'BBy925mRlgQ',
#  '31vzntYFmhs',
#  'yXkW2dCgdTc',
#  '2AkKdv5jYNM',
#  'kP26t4C1s3E',
#  'GpRoHCscVbo',
#  '43KykUjHzJw',
#  '2YiHVbVEAzM',
#  'XWRTryx6hLk',
#  'QQQ4c-_aS1c',
#  'ZaCkuPClWDY',
#  '9X-EFADjK8o',
#  'vo6UZjwCBYM',
#  '8C6HKWF4RLY',
#  'loHZtR03qhw',
#  'QqNELgn1dLc',
#  'TMoKTbJbDXg',
#  'qKDN9qlvKvc',
#  'kQM0rDGXYGc',
#  'u4gjU3uh_JQ',
#  'TC82BWKWkyI',
#  'n0HQSXBe9_Y',
#  'HjrLu83bOVA',
#  'QW5B81urhfg',
#  'lQNzHc4wnIA',
#  'rZXVa9DhMY8',
#  'rNSHHE7H2uM',
#  'BHCjsIV5L1s',
#  '1zachg1ZawU',
#  'VFdK-kseWng',
#  'Rtr2kyqhJ34',
#  'voyvJTr39Wk',
#  'JdSfpU3dNyk',
#  'scauNEvJeOE',
#  'EN37XDczHq4',
#  'Z3oc6nqH2EY',
#  'hrjD5tM5IY8',
#  '6b_IwOl3BME',
#  'nff4Me8QebQ',
#  'WqLZG9Xa5Fc',
#  'NbH4EO8Q5do',
#  'r20lh0B27v0',
#  'Qpo9RnIonLU',
#  'Haq-7Bpk4UA',
#  '2bxpdoUHH-o',
#  'u7dKpPN-kVw',
#  'EjJThNaFCFg',
#  'AFzq5V02G4Q',
#  'V1m-__vuX1E',
#  '1jD0QnM92Yw',
#  'lbgF4tiD-KY',
#  'y5O2Uhfck-g',
#  's7uYfvRByt8',
#  '0XEAQFBRRDU',
#  'TFZ-Uv1D8xU',
#  'Pr-KjW9QpuM',
#  'ng2oI3j_rpA',
#  '-IjXaue3woE',
#  'tJQw4SBeTIQ',
#  'Q3EWURJC914',
#  'uI1mS8TGZa0',
#  'n3ldo2a3Oog',
#  'T7CSdujNWpE',
#  '7cGqX7W4WYk',
#  'kToh01wX-80',
#  'sz778qsEJLs',
#  'n8rHpgqrwHg',
#  'AWWJoq6Td6A',
#  'fnSdKRkM2Y8',
#  'SRmpt7Yr2sU',
#  'gSKTHIDiqP4',
#  'xPGZSxWjoa8',
#  'Q7qLL4rQwAo',
#  '3kJqQ3ZqFTo',
#  'NLFYRK-lc7Q',
#  '7HbgEisHZ84',
#  'yNdXdZfYksM',
#  'hmdTnDgVrQY',
#  'Q8OEnOtAgro',
#  'nRMF5AA3dgc',
#  'cvYe7Yv4RL8',
#  '5g5JwNd46z8',
#  'dQnhUouCMOk',
#  'PwgF-Nu76ms',
#  'VgOlN_1j0_g',
#  'rQRxSVZveYA',
#  '1-8YBc6J4h4',
#  'xSdKqqtYOEs',
#  'Z6yVVRzqlJQ',
#  'oYKVyLbNIgs',
#  'skuF07Z6WI4',
#  '89rJNPtdkho',
#  '0_T3zeql97U',
#  'yELkZVOesPg',
#  '8ZjWlo0MLys',
#  'QTNXncitob4',
#  '4XUD8FDHAa0',
#  'Zozb5zYbFiQ',
#  'loSj6VvnPaY',
#  'bVLLwmH646k',
#  'DAMJW0tl2LI',
#  '_0Vn5K0-UVk',
#  'Rn2WB9Ct57U',
#  'YUj2iHpKAHc',
#  'v1k3FU_SMPc',
#  'tPOh7kCbTss',
#  ...]

# %% [markdown]
# ### Function to get Vedio Details

# %%
def get_video_details(youtube, video_ids):

    all_video_stats = []

    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part = 'snippet, statistics, contentDetails', 
            id=','.join(video_ids[i:i+50]))
        response = request.execute()

        for video in response['items']:
            video_stats = dict(
                Title = video['snippet']['title'],
                Publish_Date = video['snippet']['publishedAt'],
                Description = video['snippet']['description'],
                Views = video['statistics']['viewCount'],
                Likes = video['statistics'].get('likeCount',''),
                Duration=video['contentDetails'].get('duration', ''),
                Comments=video['statistics'].get('commentCount', '')
                )
            all_video_stats.append(video_stats)

    return all_video_stats

# %%
video_details = get_video_details(youtube, video_ids)

# %%
video_data = pd.DataFrame(video_details)

# %%
video_data
# Out:
#                                                   Title          Publish_Date
# 0     CDS live from Unacademy Classroom in Chandigar...  2023-06-16T20:12:25Z  \
# 1     NDA/AGNIPATH/AFCAT/ICG | DAILY PRACTICE PAPER ...  2023-06-14T16:13:22Z
# 2     RANKERS SERIES | Most Expected Qs NDA 2 2023 M...  2023-06-15T14:04:07Z
# 3     SSC GD 2023 | SSC GD New Vacancy 2023-24 | 23 ...  2023-06-16T09:49:25Z
# 4     CAPF AC 2023 | Cracking Code of CAPF AC Paper ...  2023-06-16T11:22:15Z
# ...                                                 ...                   ...
# 2394  Do not get addicted to Mobile Phones | Maj Gen...  2022-10-07T10:04:59Z
# 2395  Special Classes with Maj Gen Yash Mor | SSB In...  2022-10-06T13:50:41Z
# 2396  Biggest Defence Seminar | Maj Gen Yash Mor | A...  2022-10-01T08:30:13Z
# 2397  The most OP Educators of India at one place❤️‍...  2022-09-29T15:52:21Z
# 2398  Unacademy Defence Gurukul |  One Stop Solution...  2022-09-27T10:35:33Z
#
#                                             Description Views Likes
# 0     📌 To know more about Unacademy Offline classes...   178    10  \
# 1     📌 Check Out the Batch Below : \n🔴 Shoorveer Ai...   142    12
# 2     👉🏻Check Out the Batches Below:\n🔴 Agni NDA 2 C...   152    36
# 3     📌 Check Out the Batches Below👇:\nUSE CODE - DE...  2248   321
# 4     📌 Important Links👇:\n🔴 CDS/AFCAT/CAPF - https:...   119    20
# ...                                                 ...   ...   ...
# 2394  Unacademy Udaan AFCAT: Batch Course 2023 : htt...  2012   384
# 2395  Dear Learners,\n\nStay tuned to this channels ...   888   145
# 2396  Watch the live stream of biggest ever Defence ...  6195   546
# 2397  Meet India's most loved educators on the bigge...  4276   417
# 2398  Unacademy Udaan AFCAT: Batch Course 2023 : htt...  4419   583
#
#         Duration Comments
# 0       PT40M51S        0
# 1     PT4H12M52S        0
# 2     PT4H18M18S        0
# 3     PT5H25M50S        0
# 4      PT4H27M8S        0
# ...          ...      ...
# 2394     PT1M18S       21
# 2395     PT1M29S       17
# 2396  PT2H58M35S       22
# 2397      PT1M4S       43
# 2398        PT2M       19
#
# [2399 rows x 7 columns]

# %%
video_data.to_csv("Unacademy Defence Gurukul_All_vedios_data.csv", index=False)
